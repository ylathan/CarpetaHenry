# %% [markdown]
# <a href="https://colab.research.google.com/github/ylathan/CarpetaHenry/blob/ensayo/Homework_2_M1_Resuelto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Abrir el archivo "Emisiones_CO2.csv" y cargar sus datos en un diccionario.

# %% [markdown]
# **Cómo analizar un dataset? (la lógica general)**
#
# Siempre sigue este orden:
#
# 1.Identificar las variables
#
# 2.Entender los tipos de datos
#
# 3.Clasificar el tipo de variable
#
# 4.Buscar valores faltantes
#
# 5.Responder una pregunta concreta con filtros y agregaciones

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import os
archivo = open('Emisiones_CO2.csv', 'r', encoding='latin-1')

# %%
dicc_emisiones = {  'cod_pais' : [],
                    'nom_pais' : [],
                    'region' : [],
                    'anio' : [],
                    'co2' : [],
                    'co2_percapita' : []}

# %%
# Opción 1
next(archivo)
for linea in archivo:
    linea = linea.strip()
    campos = linea.split('|')
    dicc_emisiones['cod_pais'].append(campos[0])
    dicc_emisiones['nom_pais'].append(campos[1])
    dicc_emisiones['region'].append(campos[2])
    dicc_emisiones['anio'].append(campos[3])
    dicc_emisiones['co2'].append(campos[4])
    dicc_emisiones['co2_percapita'].append(campos[5])

# %%
print(linea)
# Out:
# ZWE|Zimbabue|África subsahariana|2011|9.860,56|0,691697897

# %%
print(campos)
# Out:
# ['ZWE', 'Zimbabue', 'África subsahariana', '2011', '9.860,56', '0,691697897']

# %%
print(dicc_emisiones['cod_pais'][:5])
print(dicc_emisiones['anio'][:5])
# Out:
# ['ABW', 'ABW', 'ABW', 'ABW', 'ABW']
# ['1960', '1961', '1962', '1963', '1964']

# %%
for i,linea in enumerate(archivo):
  if i==5:
    break
  linea =linea.strip()
  campos=linea.split('|')
  print(campos)
# Out:
# ['Código de país', 'Nombre del país', 'Región', 'Año', 'CO2 (kt)', 'CO2 per cápita (toneladas métricas)']
# ['ABW', 'Aruba', 'América Latina y Caribe', '1960', '', '']
# ['ABW', 'Aruba', 'América Latina y Caribe', '1961', '', '']
# ['ABW', 'Aruba', 'América Latina y Caribe', '1962', '', '']
# ['ABW', 'Aruba', 'América Latina y Caribe', '1963', '', '']

# %%
#cantidad de datos
len(dicc_emisiones['cod_pais'])
# Out:
# 11127

# %%
# Opción 2
encabezado = True
for linea in archivo:
    if (not encabezado):
        campos = linea.split(sep='|')
        dicc_emisiones['cod_pais'].append(campos[0])
        dicc_emisiones['nom_pais'].append(campos[1])
        dicc_emisiones['region'].append(campos[2])
        dicc_emisiones['anio'].append(campos[3])
        dicc_emisiones['co2'].append(campos[4])
        dicc_emisiones['co2_percapita'].append(campos[5])
    else:
        encabezado = False

# %%
archivo.close()

# %% [markdown]
# 2) a) ¿Cuántas variables hay? <br>
# b) ¿Qué tipos de datos usar para cada una? <br>
# c) ¿Qué tipo de variables son? <br>
# d) ¿Hay valores faltantes? <br>
# e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?

# %%
for clave, lista in dicc_emisiones.items():
    print(clave,lista.count(""))
# Out:
# cod_pais 0
# nom_pais 0
# region 0
# anio 0
# co2 2089
# co2_percapita 0

# %% [markdown]
# **Respuesta de preguntas:**
# a)Variables = columnas
# tengo 6 varibles que son : codigo del país, nombre del país, región, año,CO2, y CO2 percapital.
#
# b) Para el código, nombre del país y región usar: *str*; para el año usar: *int*; para CO2, CO2 percapital usar: *float*
#
# c) como hace referencia a la parte **estadística**, entonces:
# las primeras 3 columnas son : **cualitativas nominales**; el año es : **cuantitativo discreto** y las últimas dos son: **cuantitativas continuas**.
#
# d) hay valores faltantes y son los de la clave: CO2, con un total de 2089.

# %%
i = 100
print(i)
print(dicc_emisiones['cod_pais'][i])
print(dicc_emisiones['nom_pais'][i])
print(dicc_emisiones['region'][i])
print(dicc_emisiones['anio'][i])
print(dicc_emisiones['co2'][i])
print(dicc_emisiones['co2_percapita'][i])
# Out:
# 100
# AND
# Andorra
# Europa y Asia Central
# 2008
# 539,049
# 6,296124556

# %%
for indice, elemento in enumerate(dicc_emisiones['co2']):
    elemento = elemento.replace('.','')
    elemento = elemento.replace(',','.')
    if (elemento != ''):
        elemento = float(elemento)
    else:
        elemento = None
    dicc_emisiones['co2'][indice] = elemento

# %%
for indice, elemento in enumerate(dicc_emisiones['co2_percapita']):
    elemento = elemento.replace('\n','')
    elemento = elemento.replace('.','')
    elemento = elemento.replace(',','.')
    if (elemento != ''):
        elemento = float(elemento)
    else:
        elemento = None
    dicc_emisiones['co2_percapita'][indice] = elemento

# %%
filtro_region = 'América Latina y Caribe'
filtro_anio = '2010'
emisiones = 0
for indice, elemento in enumerate(dicc_emisiones['region']):
    if (dicc_emisiones['region'][indice] == filtro_region):
        if (dicc_emisiones['anio'][indice] == filtro_anio):
            if (dicc_emisiones['co2'][indice] != None):
                emisiones += dicc_emisiones['co2'][indice]
print('Las emisiones en', filtro_region, 'en', filtro_anio, 'fueron de',emisiones,'kt')
# Out:
# Las emisiones en América Latina y Caribe en 2010 fueron de 1691634.8009999995 kt
